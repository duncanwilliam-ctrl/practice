# %% [markdown]
# <a href="https://colab.research.google.com/github/duncanwilliam-ctrl/practice/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# practicing or testing snippets of code

# %%
from math import pi
import random
#
def routine(num1, num2):
	bartok = ((((num1 *num2) + (num1 / num2)) - num2 +num1) / num1)
	return bartok
#
# output numbers with routine results and two different randoms.
output = routine(-67, -238)
out2 = 100 * random.random()
out3 = random.randint(1, 100)
#
# formated output text with rounding
print(f"Result will be:\n", {output}, "\nand always pi; ",pi, "\n",    round(out2),     out3 )
# Out:
# Result will be:
#  {-240.55644048664243}
# and always pi;  3.141592653589793
#  40 72

# %%
sponge = int(input("Give me something: "))
bloom = ((((sponge /3) + 45) * 2) /6) - sponge
print(f"the result is: ", {bloom}, "there you go" )
# Out:
# Give me something: 23
# the result is:  {-5.444444444444446} there you go

# %% [markdown]
# add some more text from menu bar.
